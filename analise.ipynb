# %%
import pandas as pd

# %%
# Carregamento de Dados do PIB
dados_pib = pd.read_excel('/Users/willianribeiro/Documents/GitHub/enriquecimento-dados-sympla/Data/Dados-IBGE/PIB/PIB dos Munic°pios - base de dados 2010-2021.xlsx')

dados_pib.head()
# Out:
#     Ano  Código da Grande Região Nome da Grande Região  \
# 0  2010                        1                 Norte
# 1  2010                        1                 Norte
# 2  2010                        1                 Norte
# 3  2010                        1                 Norte
# 4  2010                        1                 Norte
#
#    Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                              11                            RO
# 1                              11                            RO
# 2                              11                            RO
# 3                              11                            RO
# 4                              11                            RO
#
#   Nome da Unidade da Federação  Código do Município      Nome do Município  \
# 0                     Rondônia              1100015  Alta Floresta D'Oeste
# 1                     Rondônia              1100023              Ariquemes
# ...

# %%
len(dados_pib.columns)
# Out:
# 43

# %%
# %load_ext sql

# %%
# %sql sqlite:///Database/sympla_ibge_composed_data.sqlite3
# Out:
# Connecting to 'sqlite:///Database/sympla_ibge_composed_data.sqlite3'

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
# Running query in 'sqlite:///Database/sympla_ibge_composed_data.sqlite3'
# +------------------+
# |       name       |
# +------------------+
# | dados_composicao |
# |    dados_pib     |
# +------------------+

# %%
# %sql --persist dados_pib
# Out:
# Running query in 'sqlite:///dados_sympla.sqlite3'
# Success! Persisted dados_pib to the database.

# %%
# %%sql
# SELECT *
# FROM dados_pib
# LIMIT 5
# Out:
# Running query in 'sqlite:///dados_sympla.sqlite3'
# ...

# %%
dados_composicao = pd.read_excel('/Users/willianribeiro/Documents/GitHub/enriquecimento-dados-sympla/Data/Dados-IBGE/COMPOSICAO-POPULACAO/composição-populacao-5-9-anos.xlsx', skiprows=7, header=None)

# %%
dados_composicao.head()
# Out:
#     0          1                           2           3       4       5
# 0  MU  1100015.0  Alta Floresta D'Oeste (RO)  5 a 9 anos   789.0   733.0
# 1  MU  1100023.0              Ariquemes (RO)  5 a 9 anos  3777.0  3424.0
# 2  MU  1100031.0                 Cabixi (RO)  5 a 9 anos   171.0   179.0
# 3  MU  1100049.0                 Cacoal (RO)  5 a 9 anos  2923.0  2910.0
# 4  MU  1100056.0             Cerejeiras (RO)  5 a 9 anos   554.0   594.0

# %%
dados_composicao.columns = ['nivel', 'codigo', 'nome_unidade', 'idade', 'homens', 'mulheres']

# %%
dados_composicao.head()
# Out:
#   nivel     codigo                nome_unidade       idade  homens  mulheres
# 0    MU  1100015.0  Alta Floresta D'Oeste (RO)  5 a 9 anos   789.0     733.0
# 1    MU  1100023.0              Ariquemes (RO)  5 a 9 anos  3777.0    3424.0
# 2    MU  1100031.0                 Cabixi (RO)  5 a 9 anos   171.0     179.0
# 3    MU  1100049.0                 Cacoal (RO)  5 a 9 anos  2923.0    2910.0
# 4    MU  1100056.0             Cerejeiras (RO)  5 a 9 anos   554.0     594.0
